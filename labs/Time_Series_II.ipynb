# %% [markdown]
# #  Time series advanced operations

# %% [markdown]
# **Learning Objectives:**
#   * Gain an introduction to advanced time series operation using the *pandas* library

# %% [markdown]
# ## Library import
#
# The following line imports the *pandas* library

# %%
import pandas as pd

# %% [markdown]
# ## Data loading and DataFrame creation

# %% [markdown]
# . The following example loads an external file data into a new `DataFrame`

# %%
PanelDataFrame = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/server_util.csv', parse_dates=['datetime'])

# %% [markdown]
# Let's display the first few records of the `DataFrame`:

# %%
PanelDataFrame.head()
# Out:
#              datetime  server_id  cpu_utilization  free_memory  session_count
# 0 2019-03-06 00:00:00        100             0.40         0.54             52
# 1 2019-03-06 01:00:00        100             0.49         0.51             58
# 2 2019-03-06 02:00:00        100             0.49         0.54             53
# 3 2019-03-06 03:00:00        100             0.44         0.56             49
# 4 2019-03-06 04:00:00        100             0.42         0.52             54

# %%
PanelDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40800 entries, 0 to 40799
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         40800 non-null  datetime64[ns]
#  1   server_id        40800 non-null  int64
#  2   cpu_utilization  40800 non-null  float64
#  3   free_memory      40800 non-null  float64
#  4   session_count    40800 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 1.6 MB

# %% [markdown]
# ## Time series DataFrame Operations: Indexing and sorting

# %% [markdown]
# ### It is advisable to use timestamps as indexes if you need to perform time-related operations

# %%
PanelDataFrame.set_index('datetime',inplace=True)

# %%
PanelDataFrame

# %% [markdown]
# ### It is also advisable to have the index sorted

# %%
PanelDataFrame.sort_index(inplace=True)

# %%
PanelDataFrame.head(10)
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-06        100             0.40         0.54             52
# 2019-03-06        135             0.50         0.55             55
# 2019-03-06        110             0.54         0.40             61
# 2019-03-06        136             0.58         0.40             64
# 2019-03-06        109             0.57         0.41             61
# 2019-03-06        137             0.76         0.21             78
# 2019-03-06        108             0.76         0.28             82
# 2019-03-06        138             0.43         0.57             48
# 2019-03-06        107             0.69         0.36             73
# 2019-03-06        139             0.74         0.29             78

# %% [markdown]
# ## Time series DataFrame Operations: Shifting

# %%
PanelDataFrame.shift(periods=3).head(10)
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-06        NaN              NaN          NaN            NaN
# 2019-03-06        NaN              NaN          NaN            NaN
# 2019-03-06        NaN              NaN          NaN            NaN
# 2019-03-06      100.0             0.40         0.54           52.0
# 2019-03-06      135.0             0.50         0.55           55.0
# 2019-03-06      110.0             0.54         0.40           61.0
# 2019-03-06      136.0             0.58         0.40           64.0
# 2019-03-06      109.0             0.57         0.41           61.0
# 2019-03-06      137.0             0.76         0.21           78.0
# 2019-03-06      108.0             0.76         0.28           82.0

# %%
PanelDataFrame.shift(periods=-3).head(10)
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-06      136.0             0.58         0.40           64.0
# 2019-03-06      109.0             0.57         0.41           61.0
# 2019-03-06      137.0             0.76         0.21           78.0
# 2019-03-06      108.0             0.76         0.28           82.0
# 2019-03-06      138.0             0.43         0.57           48.0
# 2019-03-06      107.0             0.69         0.36           73.0
# 2019-03-06      139.0             0.74         0.29           78.0
# 2019-03-06      140.0             0.66         0.36           74.0
# 2019-03-06      106.0             0.46         0.55           45.0
# 2019-03-06      141.0             0.53         0.39           56.0

# %%
PanelDataFrame.loc['2019-04-08']
# Out:
#                      server_id  cpu_utilization  free_memory  session_count  \
# datetime
# 2019-04-08 00:00:00        106             0.44         0.62             49
# 2019-04-08 00:00:00        112             0.72         0.29             81
# 2019-04-08 00:00:00        100             0.43         0.54             51
# 2019-04-08 00:00:00        137             0.75         0.28             83
# 2019-04-08 00:00:00        110             0.61         0.40             62
# ...                        ...              ...          ...            ...
# 2019-04-08 23:00:00        128             0.64         0.41             64
# 2019-04-08 23:00:00        127             0.67         0.33             78
# 2019-04-08 23:00:00        126             0.71         0.33             73
# 2019-04-08 23:00:00        123             0.71         0.22             83
# 2019-04-08 23:00:00        149             0.75         0.24             80
#
#                      month  day datetimeInAlternativeFormat
# datetime
# 2019-04-08 00:00:00      4    8                  04/08/2019
# 2019-04-08 00:00:00      4    8                  04/08/2019
# 2019-04-08 00:00:00      4    8                  04/08/2019
# 2019-04-08 00:00:00      4    8                  04/08/2019
# 2019-04-08 00:00:00      4    8                  04/08/2019
# ...                    ...  ...                         ...
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
#
# [1200 rows x 7 columns]

# %%
# Let's select a range of observations (a.k.a slicing)

PanelDataFrame.loc['2019-03-01':'2019-05-01']
# Out:
#                      server_id  cpu_utilization  free_memory  session_count  \
# datetime
# 2019-03-06 00:00:00        100             0.40         0.54             52
# 2019-03-06 00:00:00        135             0.50         0.55             55
# 2019-03-06 00:00:00        110             0.54         0.40             61
# 2019-03-06 00:00:00        136             0.58         0.40             64
# 2019-03-06 00:00:00        109             0.57         0.41             61
# ...                        ...              ...          ...            ...
# 2019-04-08 23:00:00        128             0.64         0.41             64
# 2019-04-08 23:00:00        127             0.67         0.33             78
# 2019-04-08 23:00:00        126             0.71         0.33             73
# 2019-04-08 23:00:00        123             0.71         0.22             83
# 2019-04-08 23:00:00        149             0.75         0.24             80
#
#                      month  day datetimeInAlternativeFormat
# datetime
# 2019-03-06 00:00:00      3    6                  03/06/2019
# 2019-03-06 00:00:00      3    6                  03/06/2019
# 2019-03-06 00:00:00      3    6                  03/06/2019
# 2019-03-06 00:00:00      3    6                  03/06/2019
# 2019-03-06 00:00:00      3    6                  03/06/2019
# ...                    ...  ...                         ...
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
# 2019-04-08 23:00:00      4    8                  04/08/2019
#
# [40800 rows x 7 columns]

# %% [markdown]
# ## Time series DataFrame Operations: Downsampling

# %%
PanelDataFrame.resample("W").mean()
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-10      124.5         0.620683     0.378650      69.138500
# 2019-03-17      124.5         0.620794     0.379404      69.149167
# 2019-03-24      124.5         0.620655     0.379669      69.196667
# 2019-03-31      124.5         0.620218     0.378476      69.087500
# 2019-04-07      124.5         0.620451     0.379381      69.120357
# 2019-04-14      124.5         0.620942     0.380175      69.097500

# %%
PanelDataFrame.resample("M").mean()
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-31      124.5         0.620580      0.37908      69.143301
# 2019-04-30      124.5         0.620513      0.37948      69.117500

# %%
PanelDataFrame.resample("W").max()
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-10        149             0.89         0.68             96
# 2019-03-17        149             0.88         0.68             95
# 2019-03-24        149             0.88         0.66             94
# 2019-03-31        149             0.91         0.66             93
# 2019-04-07        149             0.88         0.66             94
# 2019-04-14        149             0.89         0.66             92

# %%
PanelDataFrame.resample("M").sum()
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-31    3884400         19362.10     11827.31        2157271
# 2019-04-30    1195200          5956.92      3643.01         663528

# %%
DownSampledPanelDataFrame=PanelDataFrame.resample("W").mean()

# %%
DownSampledPanelDataFrame
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-10      124.5         0.620683     0.378650      69.138500
# 2019-03-17      124.5         0.620794     0.379404      69.149167
# 2019-03-24      124.5         0.620655     0.379669      69.196667
# 2019-03-31      124.5         0.620218     0.378476      69.087500
# 2019-04-07      124.5         0.620451     0.379381      69.120357
# 2019-04-14      124.5         0.620942     0.380175      69.097500

# %% [markdown]
# ## Time series DataFrame Operations: Upsampling

# %%
DownSampledPanelDataFrame.resample('D').ffill()
# Out:
#             server_id  cpu_utilization  free_memory  session_count
# datetime
# 2019-03-10      124.5         0.620683     0.378650      69.138500
# 2019-03-11      124.5         0.620683     0.378650      69.138500
# 2019-03-12      124.5         0.620683     0.378650      69.138500
# 2019-03-13      124.5         0.620683     0.378650      69.138500
# 2019-03-14      124.5         0.620683     0.378650      69.138500
# 2019-03-15      124.5         0.620683     0.378650      69.138500
# 2019-03-16      124.5         0.620683     0.378650      69.138500
# 2019-03-17      124.5         0.620794     0.379404      69.149167
# 2019-03-18      124.5         0.620794     0.379404      69.149167
# 2019-03-19      124.5         0.620794     0.379404      69.149167
# 2019-03-20      124.5         0.620794     0.379404      69.149167
# 2019-03-21      124.5         0.620794     0.379404      69.149167
# 2019-03-22      124.5         0.620794     0.379404      69.149167
# 2019-03-23      124.5         0.620794     0.379404      69.149167
# 2019-03-24      124.5         0.620655     0.379669      69.196667
# 2019-03-25      124.5         0.620655     0.379669      69.196667
# 2019-03-26      124.5         0.620655     0.379669      69.196667
# 2019-03-27      124.5         0.620655     0.379669      69.196667
# 2019-03-28      124.5         0.620655     0.379669      69.196667
# 2019-03-29      124.5         0.620655     0.379669      69.196667
# 2019-03-30      124.5         0.620655     0.379669      69.196667
# 2019-03-31      124.5         0.620218     0.378476      69.087500
# 2019-04-01      124.5         0.620218     0.378476      69.087500
# 2019-04-02      124.5         0.620218     0.378476      69.087500
# 2019-04-03      124.5         0.620218     0.378476      69.087500
# 2019-04-04      124.5         0.620218     0.378476      69.087500
# 2019-04-05      124.5         0.620218     0.378476      69.087500
# 2019-04-06      124.5         0.620218     0.378476      69.087500
# 2019-04-07      124.5         0.620451     0.379381      69.120357
# 2019-04-08      124.5         0.620451     0.379381      69.120357
# 2019-04-09      124.5         0.620451     0.379381      69.120357
# 2019-04-10      124.5         0.620451     0.379381      69.120357
# 2019-04-11      124.5         0.620451     0.379381      69.120357
# 2019-04-12      124.5         0.620451     0.379381      69.120357
# 2019-04-13      124.5         0.620451     0.379381      69.120357
# 2019-04-14      124.5         0.620942     0.380175      69.097500
